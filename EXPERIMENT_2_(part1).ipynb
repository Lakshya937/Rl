# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshya937/Rl/blob/main/EXPERIMENT_2_(part1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x= np.random.randint(0,50,1000)
print(x)
# Out:
# [ 0 48 39  7 16  4 38 33 15 11 42 28 33  9 25 42  1  2 43 39  0 23 38  6
#  16 20 20 46 14  6 34 48  8 16 37 37  2  4 39 40  3 37 24 21 11 33 28 48
#   6  7 40 44  1 48 30  4 40 45  4 27 34 20 13 24 31 19 34 14 48 38 32 38
#  29 31 34 10 29 36  3  4 16 26  8 13 27 26 41 39 41 29 37  7 39 14 23 12
#  19 19 24 34 34 18 15 26 35 20  8 45 40 42 48 33 15 46 46 16 22 24 30 39
#  35 40 41 47  1  5 35 48  9  6 39  9 16 27 10 27 19 37  9 34 23 14 40 43
#  49 34  7 40 25 39 48 32 36 39 15 30 46  9 29 32 34 35 28  3 30 20 10 39
#   0 32 46 40 14 33 32 43 19 15 10 21 48 28  5  9 44 31 12 10  5 16 34 17
#  23  3 49 42 21  2  8  3 45  4 38 46 30 33 39 30  8 34  3 14 27 35 31  8
#  32 36  7 49  0  0 38 12 25 32 43 31 16 32 37  8 27 48 13 18  3 32  8 40
#  49 37  2 47  1  9 35 37  0 33 14 23 26 14 16 26 11  5 29 24 23 49 25 34
#  38 41 22 44  6 48 13 49 15 47 41 22 26  5 40  4 43  9 30 23 34 10 21 33
#  14 32  0  1  6  4 49 40 32  8 27 20 18  8 27 41 47 12  1 17 16  1 30 15
# ...

# %%
y = x+np.random.normal(0,10,1000)
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.81434215],
#        [0.81434215, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter (x,y)
plt.show()

# %%
y = 100-(x + np.random.normal(0,10,1000))
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.80896442],
#        [-0.80896442,  1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter (x,y)
plt.show()

# %%
x= np.random.randint(0,50,1000)

# %%
y= np.random.randint(0,10,1000)

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.01004563],
#        [-0.01004563,  1.        ]])

# %%
df = pd.DataFrame({'a': np.random.randint(0,50,1000)})
df['b'] = df['a'] + np.random.randint(0,10,1000)
df['c'] = 100 - df['a'] + np.random.normal(0,5,1000)
df['d'] = np.random.randint(0,50,1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.981075 -0.937696 -0.004776
# b  0.981075  1.000000 -0.920904 -0.014800
# c -0.937696 -0.920904  1.000000 -0.010106
# d -0.004776 -0.014800 -0.010106  1.000000

# %%
pd.plotting.scatter_matrix(df,figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
